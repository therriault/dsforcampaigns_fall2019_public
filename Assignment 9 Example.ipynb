# %% [markdown]
# # Assignment 9 Example
#
# *Last updated: 11/6/2019, Andrew Therriault*
#
# This notebook gives an example of what a completed Week 9 assignment might look like. It builds a forecast of the 2020 Democratic Presidential Primary based on the polls collected by 538 (using the dataset as of 11/6/2019).

# %% [markdown]
# ## Setting up the environment

# %% [markdown]
# #### Setting the working directory

# %%
import os
os.chdir('C:\\working\\')

# %% [markdown]
# #### Importing numpy and pandas for analysis and setting display options for pandas

# %%
import numpy as np

# %%
import pandas as pd
pd.options.display.max_colwidth = 1000
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %% [markdown]
# ## Loading, transforming, and exploring data

# %% [markdown]
# #### Loading just the columns we actually care about

# %%
columns_to_keep = [
    'poll_id',
    'state',
    'pollster',
    'fte_grade',
    'sample_size',
    'population',
    'methodology',
    'start_date',
    'end_date',
    'tracking',
    'answer',
    'pct']

# %%
raw = pd.read_csv('president_primary_polls.csv', usecols=columns_to_keep, parse_dates=['start_date','end_date'])

# %% [markdown]
# #### Filling in some missing data

# %%
for i in ['fte_grade','methodology']:
    raw[i] = raw[i].fillna('Missing')

# %% [markdown]
# #### Filtering to just the candidates we care about
# I'm limiting to the 9 candidates still in the race who have qualified for inclusion in the November 20th debate as of 11/5. (The only noteworthy exclusions based on this are Gabbard and Castro, but both are excluded because they don't show enough polling strength to meet the threshold, so that means they wouldn't affect a forecast much anyway.)

# %%
cands = [
    'Biden',
    'Harris',
    'Warren',
    'Sanders',
    'Booker',
    'Klobuchar',
    'Buttigieg',
    'Yang',
    'Steyer'
    ]

# %%
raw = raw[raw.answer.map(lambda x: x in cands)]

# %% [markdown]
# #### Limiting to states with at least three unique polls

# %%
raw['state'] = raw.state.fillna('National')
polls_by_state = raw.drop_duplicates(['state','poll_id']).groupby('state').poll_id.count()
states = polls_by_state[polls_by_state.map(lambda x: x >= 3)].index

# %%
raw = raw[raw.state.map(lambda x: x in states)]

# %%
raw.sample(5).T
# Out:
#                            9744                 12471                12613  \
# poll_id                    58104                57244                57185
# state                   National             National                 Iowa
# pollster         Morning Consult      Morning Consult         Selzer & Co.
# fte_grade                    B/C                  B/C                   A+
# sample_size                14830                  699                  455
# population                    lv                   rv                   lv
# methodology               Online               Online           Live Phone
# start_date   2019-05-13 00:00:00  2019-01-04 00:00:00  2018-12-10 00:00:00
# end_date     2019-05-19 00:00:00  2019-01-06 00:00:00  2018-12-13 00:00:00
# tracking                   False                False                False
# answer                     Biden               Warren               Harris
# pct                           39                    4                    5
#
#                            2724                 1918
# poll_id                    59626                59757
# state                       Iowa             National
# pollster            Selzer & Co.  Monmouth University
# fte_grade                     A+                   A+
# sample_size                  602                  434
# population                    lv                   rv
# methodology           Live Phone           Live Phone
# start_date   2019-09-14 00:00:00  2019-09-23 00:00:00
# end_date     2019-09-18 00:00:00  2019-09-29 00:00:00
# tracking                   False                False
# answer                 Klobuchar              Sanders
# pct                            3                   15

# %% [markdown]
# #### Looping over categorical variables to see value counts

# %%
for i in raw.dtypes[raw.dtypes == 'object'].index:
    print('\n{}:'.format(i))
    print(raw[i].value_counts()[:25])
# Out:
# state:
# National          3377
# New Hampshire      301
# Iowa               266
# South Carolina     251
# California         214
# Texas              152
# Florida             96
# Nevada              87
# Wisconsin           77
# Pennsylvania        55
# Michigan            50
# Massachusetts       40
# North Carolina      40
# Ohio                35
# Arizona             34
# Virginia            32
# Georgia             26
# Name: state, dtype: int64
#
# pollster:
# Harris Insights & Analytics                     1435
# Morning Consult                                  432
# Change Research                                  416
# YouGov                                           403
# Emerson College                                  252
# Ipsos                                            163
# Quinnipiac University                            162
# Monmouth University                              141
# Fox News/Beacon Research/Shaw & Co. Research      98
# SSRS                                              97
# Zogby Interactive/JZ Analytics                    90
# Suffolk University                                86
# ABC News/Washington Post                          82
# Echelon Insights                                  81
# Optimus                                           81
# Tel Opinion Research                              81
# McLaughlin & Associates                           73
# SurveyUSA                                         61
# Capitol Weekly                                    59
# University of New Hampshire                       49
# David Binder Research                             40
# Civiqs                                            36
# IBD/TIPP                                          35
# Climate Nexus                                     35
# Gravis Marketing                                  35
# Name: pollster, dtype: int64
#
# fte_grade:
# C+         1493
# B/C         716
# B-          566
# C           515
# A-          436
# Missing     402
# A+          272
# A/B         261
# B+          162
# C/D         154
# B            79
# A            61
# D-           16
# Name: fte_grade, dtype: int64
#
# population:
# lv    3212
# rv    1724
# a      182
# v       15
# Name: population, dtype: int64
#
# methodology:
# Online               3467
# Live Phone           1160
# IVR/Online            243
# Live Phone/Text        90
# Online/IVR             77
# Live Phone/Online      61
# Missing                22
# IVR/Text                7
# Automated Phone         6
# Name: methodology, dtype: int64
#
# answer:
# Biden        641
# Warren       638
# Sanders      635
# Harris       625
# Booker       595
# Klobuchar    574
# Buttigieg    570
# Yang         529
# Steyer       326
# Name: answer, dtype: int64

# %% [markdown]
# #### Creating dataframe of polls for merging later (this is to allow for cleaning up polls which publish multiple sets of results)

# %% [markdown]
# Looking at poll_ids with multiple sets of results

# %%
polls = raw[['poll_id', 'state', 'pollster', 'fte_grade', 'sample_size', 'population', 'methodology',
                'start_date', 'end_date', 'tracking']].drop_duplicates()
result_count = polls.poll_id.value_counts()
multi_results = result_count[result_count > 1].index
polls[polls.poll_id.map(lambda x: x in multi_results)].sort_values(by='poll_id')[:20]
# Out:
#        poll_id     state                     pollster fte_grade  sample_size  \
# 12656    57064  National                         SSRS       A/B          424
# 12636    57064  National                         SSRS       A/B          463
# 12700    57182  National  Harris Insights & Analytics        C+          449
# 12692    57182  National  Harris Insights & Analytics        C+          459
# 12408    57376  National  Harris Insights & Analytics        C+          488
# 12420    57376  National  Harris Insights & Analytics        C+          479
# 11834    57583  National  Harris Insights & Analytics        C+          346
# 11846    57583  National  Harris Insights & Analytics        C+          337
# 11307    57700  National                         SSRS       A/B          411
# 11290    57700  National                         SSRS       A/B          456
# 11062    57787  National  Harris Insights & Analytics        C+          263
# 11045    57787  National  Harris Insights & Analytics        C+          273
# 10712    57889  National        USC Dornsife/LA Times       B/C         1131
# 10696    57889  National        USC Dornsife/LA Times       B/C         2196
# 10199    57998  National  Harris Insights & Analytics        C+          254
# 10222    57998  National  Harris Insights & Analytics        C+          259
# 9819     58081  National                        Ipsos        B-         1132
# 9842     58081  National                        Ipsos        B-          964
# 9134     58389  National                        Ipsos        B-         2271
# 9110     58389  National                        Ipsos        B-         2525
#
#       population methodology start_date   end_date  tracking
# 12656         rv  Live Phone 2018-12-06 2018-12-09     False
# 12636          a  Live Phone 2018-12-06 2018-12-09     False
# 12700         rv      Online 2018-11-27 2018-11-28     False
# 12692         rv      Online 2018-11-27 2018-11-28     False
# 12408         rv      Online 2019-01-15 2019-01-16     False
# 12420         rv      Online 2019-01-15 2019-01-16     False
# 11834         rv      Online 2019-02-19 2019-02-20     False
# 11846         rv      Online 2019-02-19 2019-02-20     False
# 11307         rv  Live Phone 2019-03-14 2019-03-17     False
# 11290          a  Live Phone 2019-03-14 2019-03-17     False
# 11062         rv      Online 2019-03-25 2019-03-26     False
# 11045         rv      Online 2019-03-25 2019-03-26     False
# 10712         lv      Online 2019-03-15 2019-04-15     False
# 10696         lv      Online 2019-03-15 2019-04-15     False
# 10199         rv      Online 2019-04-30 2019-05-01     False
# 10222         rv      Online 2019-04-30 2019-05-01     False
# 9819           a      Online 2019-05-10 2019-05-14     False
# 9842          rv      Online 2019-05-10 2019-05-14     False
# 9134          rv      Online 2019-05-29 2019-06-05     False
# 9110           a      Online 2019-05-29 2019-06-05     False

# %% [markdown]
# Limiting to the set of results with the smallest sample size for each poll, which is the tightest screen (likely voters before registered voters, registered voters before all adults, etc.)

# %%
polls = polls.sort_values(by='sample_size',ascending=True).drop_duplicates('poll_id')

# %% [markdown]
# Calculating age of polls and duration in the field

# %%
polls['age'] = (pd.Timestamp('now') - polls.end_date).dt.days
polls['duration'] = (polls.end_date - polls.start_date).dt.days + 1

# %%
polls.head()
# Out:
#       poll_id           state                        pollster fte_grade  \
# 9463    58460  South Carolina  Zogby Interactive/JZ Analytics         C
# 9388    58455         Arizona  Zogby Interactive/JZ Analytics         C
# 2263    62437        Michigan                  Denno Research   Missing
# 9433    58458            Ohio  Zogby Interactive/JZ Analytics         C
# 353     62520    Pennsylvania     Franklin & Marshall College       B/C
#
#       sample_size population methodology start_date   end_date  tracking  age  \
# 9463          183         lv      Online 2019-05-23 2019-05-29     False  161
# 9388          197         lv      Online 2019-05-23 2019-05-29     False  161
# 2263          217         lv  Live Phone 2019-09-21 2019-09-24     False   43
# 9433          222         lv      Online 2019-05-23 2019-05-29     False  161
# 353           226         rv  Live Phone 2019-10-21 2019-10-27     False   10
#
#       duration
# 9463         7
# 9388         7
# 2263         4
# 9433         7
# 353          7

# %% [markdown]
# #### Joining in results that match to those included poll_ids (with all the other fields matching)

# %%
results = polls.merge(raw, how='inner', on=['poll_id', 'state', 'pollster', 'fte_grade', 'sample_size', 'population', 
                                            'methodology', 'start_date', 'end_date', 'tracking'])
results.head()
# Out:
#    poll_id           state                        pollster fte_grade  \
# 0    58460  South Carolina  Zogby Interactive/JZ Analytics         C
# 1    58460  South Carolina  Zogby Interactive/JZ Analytics         C
# 2    58460  South Carolina  Zogby Interactive/JZ Analytics         C
# 3    58460  South Carolina  Zogby Interactive/JZ Analytics         C
# 4    58460  South Carolina  Zogby Interactive/JZ Analytics         C
#
#    sample_size population methodology start_date   end_date  tracking  age  \
# 0          183         lv      Online 2019-05-23 2019-05-29     False  161
# 1          183         lv      Online 2019-05-23 2019-05-29     False  161
# 2          183         lv      Online 2019-05-23 2019-05-29     False  161
# 3          183         lv      Online 2019-05-23 2019-05-29     False  161
# 4          183         lv      Online 2019-05-23 2019-05-29     False  161
#
#    duration     answer   pct
# 0         7      Biden  36.2
# 1         7    Sanders  13.2
# 2         7     Warren  12.2
# 3         7  Buttigieg   6.9
# 4         7     Harris   3.8

# %% [markdown]
# #### Averaging across a handful of remaining duplicate entries
# There aren't many of these, so I'm assuming they're additional variants not captured in the standard columns, and rather than deal with them individually I'm just averaging the results across them.

# %%
results = results.groupby(['poll_id', 'state', 'pollster', 'fte_grade', 'sample_size', 'population', 
                            'methodology', 'start_date', 'end_date', 'tracking', 'answer']
                            ).pct.mean().reset_index()
results.head()
# Out:
#    poll_id     state         pollster fte_grade  sample_size population  \
# 0    56853  National  Morning Consult       B/C          733         rv
# 1    56853  National  Morning Consult       B/C          733         rv
# 2    56853  National  Morning Consult       B/C          733         rv
# 3    56853  National  Morning Consult       B/C          733         rv
# 4    56853  National  Morning Consult       B/C          733         rv
#
#   methodology start_date   end_date  tracking     answer   pct
# 0      Online 2018-11-07 2018-11-09     False      Biden  26.0
# 1      Online 2018-11-07 2018-11-09     False     Booker   3.0
# 2      Online 2018-11-07 2018-11-09     False     Harris   4.0
# 3      Online 2018-11-07 2018-11-09     False  Klobuchar   1.0
# 4      Online 2018-11-07 2018-11-09     False    Sanders  19.0

# %% [markdown]
# #### Pivoting long to wide (one column per candidate), filling in with zeros, and calculating undecideds

# %%
results_wide = results.pivot(index='poll_id', columns='answer', values='pct').fillna(0)
results_wide['TOTAL'] = results_wide.sum(axis=1)
results_wide['UNDECIDED'] = 100 - results_wide['TOTAL']
results_wide.head(10)
# Out:
# answer   Biden  Booker  Buttigieg  Harris  Klobuchar  Sanders  Steyer  Warren  \
# poll_id
# 56853     26.0     3.0        0.0     4.0        1.0     19.0     0.0     5.0
# 57064     33.0     6.0        0.0     4.0        3.0     14.0     0.0     4.0
# 57075     25.5     0.0        0.0     8.5        0.0     22.0     0.0     6.9
# 57144     25.0     3.0        0.0     3.0        1.0     15.0     0.0     3.0
# 57181     19.0     3.0        0.0     6.0        3.0     14.0     0.0    11.0
# 57182     28.0     4.0        0.0     3.0        0.0     21.0     0.0     5.0
# 57183     17.0     2.0        0.0     3.0        1.0     18.0     0.0     4.0
# 57184     30.0     5.0        0.0     5.0        0.0     20.0     0.0     5.0
# 57185     32.0     4.0        0.0     5.0        3.0     19.0     0.0     8.0
# 57186     30.0     6.0        0.0     7.0       10.0     13.0     0.0     9.0
#
# answer   Yang  TOTAL  UNDECIDED
# poll_id
# 56853     0.0   58.0       42.0
# 57064     0.0   64.0       36.0
# 57075     0.0   62.9       37.1
# 57144     0.0   50.0       50.0
# 57181     0.0   56.0       44.0
# 57182     0.0   61.0       39.0
# 57183     0.0   45.0       55.0
# 57184     0.0   65.0       35.0
# 57185     0.0   71.0       29.0
# 57186     0.0   75.0       25.0

# %% [markdown]
# #### Making the final dataframe

# %%
data = polls.merge(results_wide, on='poll_id').set_index('poll_id').sort_index()
data.head(20)
# Out:
#                  state                        pollster fte_grade  sample_size  \
# poll_id
# 56853         National                 Morning Consult       B/C          733
# 57064         National                            SSRS       A/B          424
# 57075         National                 Emerson College        A-          320
# 57144         National                 Morning Consult       B/C          706
# 57181    Massachusetts                          YouGov        B-          655
# 57182         National     Harris Insights & Analytics        C+          449
# 57183         National         McLaughlin & Associates       C/D          468
# 57184         National     Harris Insights & Analytics        C+          370
# 57185             Iowa                    Selzer & Co.        A+          455
# 57186             Iowa           David Binder Research   Missing          500
# 57187         National                 Change Research         C         2968
# 57188             Iowa                 Change Research         C         1291
# 57223    New Hampshire                 Change Research         C         1162
# 57244         National                 Morning Consult       B/C          699
# 57326         National                 Morning Consult       B/C          674
# 57366         National  Zogby Interactive/JZ Analytics         C          410
# 57374         National                 Emerson College        A-          355
# 57376         National     Harris Insights & Analytics        C+          479
# 57380         National                 Morning Consult       B/C          694
# 57396         National        ABC News/Washington Post        A+          447
#
#         population methodology start_date   end_date  tracking  age  duration  \
# poll_id
# 56853           rv      Online 2018-11-07 2018-11-09     False  362         3
# 57064           rv  Live Phone 2018-12-06 2018-12-09     False  332         4
# 57075           lv  IVR/Online 2018-12-06 2018-12-09     False  332         4
# 57144           rv      Online 2018-12-14 2018-12-16     False  325         3
# 57181           rv      Online 2018-11-07 2018-11-14     False  357         8
# 57182           rv      Online 2018-11-27 2018-11-28     False  343         2
# 57183           lv      Online 2018-12-10 2018-12-14     False  327         5
# 57184           rv      Online 2018-11-05 2018-11-06     False  365         2
# 57185           lv  Live Phone 2018-12-10 2018-12-13     False  328         4
# 57186           lv  Live Phone 2018-12-10 2018-12-11     False  330         2
# 57187           lv      Online 2018-12-13 2018-12-17     False  324         5
# 57188           lv      Online 2018-12-13 2018-12-17     False  324         5
# 57223           lv      Online 2019-01-02 2019-01-03     False  307         2
# 57244           rv      Online 2019-01-04 2019-01-06     False  304         3
# 57326           rv      Online 2019-01-11 2019-01-14     False  296         4
# 57366           lv      Online 2019-01-18 2019-01-20     False  290         3
# 57374           lv  IVR/Online 2019-01-20 2019-01-21     False  289         2
# 57376           rv      Online 2019-01-15 2019-01-16     False  294         2
# 57380           rv      Online 2019-01-18 2019-01-22     False  288         5
# 57396            a  Live Phone 2019-01-21 2019-01-24     False  286         4
#
#          Biden  Booker  Buttigieg  Harris  Klobuchar  Sanders  Steyer  Warren  \
# poll_id
# 56853     26.0     3.0        0.0    4.00        1.0     19.0     0.0     5.0
# 57064     33.0     6.0        0.0    4.00        3.0     14.0     0.0     4.0
# 57075     25.5     0.0        0.0    8.50        0.0     22.0     0.0     6.9
# 57144     25.0     3.0        0.0    3.00        1.0     15.0     0.0     3.0
# 57181     19.0     3.0        0.0    6.00        3.0     14.0     0.0    11.0
# 57182     28.0     4.0        0.0    3.00        0.0     21.0     0.0     5.0
# 57183     17.0     2.0        0.0    3.00        1.0     18.0     0.0     4.0
# 57184     30.0     5.0        0.0    5.00        0.0     20.0     0.0     5.0
# 57185     32.0     4.0        0.0    5.00        3.0     19.0     0.0     8.0
# 57186     30.0     6.0        0.0    7.00       10.0     13.0     0.0     9.0
# 57187     21.0     4.0        0.0    8.00        3.0     16.0     1.0     7.0
# 57188     20.0     4.0        0.0    7.00        5.0     20.0     0.0     7.0
# 57223     24.0     3.0        0.0    4.00        2.0     26.0     1.0    11.0
# 57244     27.0     3.0        0.0    3.00        2.0     16.0     0.0     4.0
# 57326     32.0     2.0        0.0    6.00        1.0     15.0     0.0     9.0
# 57366     26.0     2.0        0.0    5.50        0.0     15.0     0.0     7.0
# 57374     45.4     7.7        0.0   10.75        1.4      5.4     0.0    22.9
# 57376     23.0     3.0        0.0    7.00        0.0     21.0     0.0     4.0
# 57380     26.0     4.0        0.0    9.00        2.0     16.0     0.0     6.0
# 57396      9.0     1.0        0.0    8.00        1.0      4.0     0.0     2.0
#
#          Yang  TOTAL  UNDECIDED
# poll_id
# 56853     0.0  58.00      42.00
# 57064     0.0  64.00      36.00
# 57075     0.0  62.90      37.10
# 57144     0.0  50.00      50.00
# 57181     0.0  56.00      44.00
# 57182     0.0  61.00      39.00
# 57183     0.0  45.00      55.00
# 57184     0.0  65.00      35.00
# 57185     0.0  71.00      29.00
# 57186     0.0  75.00      25.00
# 57187     0.0  60.00      40.00
# 57188     0.0  63.00      37.00
# 57223     0.0  71.00      29.00
# 57244     0.0  55.00      45.00
# 57326     0.0  65.00      35.00
# 57366     0.0  55.50      44.50
# 57374     0.0  93.55       6.45
# 57376     0.0  58.00      42.00
# 57380     0.0  63.00      37.00
# 57396     0.0  25.00      75.00

# %% [markdown]
# ## Setting up the forecast function
#
# This function combines poll results using the following fixed rules and options:
# * Fixed rules:
#   * Each poll result is given a weight based on a variety of different characteristics (see "options" below), and the weighted average of these is used as the forecast. (This means that we're estimating where the race stands now, not where it's going to be in the future - there's no imputation of a future state, e.g. by forecasting a trend line.)
#   * Each poll characteristic is given a weight value, and these are all multiplied together to calculate the overall weight per poll.
#   * "Undecided" is treated as a distinct response choice,
# * Options:
#   * Which state the calculation is for ("National" is treated as a separate state here)
#   * Which candidates are included
#   * Max number of poll results included per pollster (keeps only most recent)
#   * Max age of poll results included
#   * A set of pre-defined weights based on values of:
#     * fte_grade (pollster rating by 538)
#     * population
#     * methodology
#     * tracking
#   * A set of weighting functions to apply to values of:
#     * sample_size
#     * duration
#     * age
#
# Some things *not* included in here that could be:
#  * Adjusting to down-weight additional polls from the same pollster
#  * Giving lower weights to older results from the same pollster (other than because of increased age)
#  * Removing results from tracking polls with overlapping timeframes (but 538 has done some of this already, and the weight given to the "tracking" flag can partially adjust for this)

# %% [markdown]
# #### Setting pre-defined weights for values of each characteristic (as dicts)
# Adding a "Missing" option for each (which will get filled in during processing) except for Tracking, where missing values are treated as False

# %%
w_fte_grade = {
    'A+' : 4.3,
    'A' : 4.0,
    'A-' : 3.7,
    'A/B' : 3.5,
    'B+' : 3.3,
    'B' : 3.0,
    'B-' : 2.7,
    'B/C' : 2.5,
    'C+' : 2.3,
    'C' : 2.0,
    'C/D' : 1.5,
    'D-' : 0.7,
    'Missing' : 1.0 
}

# %%
w_population = {
    'lv' : 2.0,
    'rv' : 1.5,
    'v' : 1.0,
    'a' : 1.0,
    'Missing' : 1.0
}

# %%
w_methodology = {
    'Live Phone' : 3.0,
    'Live Phone/Text' : 3.0,
    'Live Phone/Online' : 3.0,
    'Online' : 2.0,
    'IVR/Text': 2.0,
    'Online/IVR' : 2.0,
    'IVR/Online' : 2.0,
    'Automated Phone': 1.0,
    'Missing' : 1.0
}

# %%
w_tracking = {
    True: 0.5,
    False: 1.0,
}

# %% [markdown]
# #### Setting weighting functions for sample size, poll age, and duration

# %%
def f_sample_size(x):
    z = np.amin([x,2000]) #topcoding at 2000 to avoid over-weighting giant online panels
    return (z**0.5)/(1000**0.5)

#showing how it works in practice
for i in [0,100,500,1000,2000,10000]:
    print('{}: {}'.format(i,f_sample_size(i)))
# Out:
# 0: 0.0
# 100: 0.31622776601683794
# 500: 0.7071067811865476
# 1000: 1.0
# 2000: 1.4142135623730951
# 10000: 1.4142135623730951

# %%
def f_age(x):
    return 3 / (x+9)**0.5

#showing how it works in practice
for i in [0,3,7,30,90,365]:
    print('{}: {}'.format(i,f_age(i)))
# Out:
# 0: 1.0
# 3: 0.8660254037844387
# 7: 0.75
# 30: 0.48038446141526137
# 90: 0.30151134457776363
# 365: 0.15512630699850574

# %%
def f_duration(x):
    if (x > 0) & (x < 4):
        return x**0.5
    elif x >= 4:
        return 2.0

#showing how it works in practice
for i in [0,1,2,3,4,5]:
    print('{}: {}'.format(i,f_duration(i)))
# Out:
# 0: None
# 1: 1.0
# 2: 1.4142135623730951
# 3: 1.7320508075688772
# 4: 2.0
# 5: 2.0

# %% [markdown]
# #### Creating the forecast function

# %%
def forecast(x, state, candidates, max_results, max_age,
                p_fte_grade, p_population, p_methodology, p_tracking,
                p_sample_size, p_age, p_duration):
    
    #limiting to the state being forecast and the max number of polls per pollster and max poll age
    x = x[x.state==state].copy()
    x['recency'] = x.sort_values(by='age', ascending=True).groupby('pollster').cumcount()
    x = x[x.recency < max_results]
    x = x[x.age <= max_age]
    
    #applying weight mappings
    x['w1'] = x.fte_grade.map(p_fte_grade)
    x['w2'] = x.population.map(p_population)
    x['w3'] = x.methodology.map(p_methodology)
    x['w4'] = x.tracking.map(p_tracking)
    x['w5'] = x.sample_size.map(p_sample_size)
    x['w6'] = x.age.map(p_age)
    x['w7'] = x.duration.map(p_duration)
    
    #calculating overall weights and adjusting to mean=1
    x['w'] = x.w1 * x.w2 * x.w3 * x.w4 * x.w5 * x.w6 * x.w7
    x['w'] = x.w / x.w.mean()
    
    #calculating forecasts
    forecast = dict()
    for i in (candidates + ['UNDECIDED']):
        forecast[i] = np.round((x[i]*x.w).sum() / x.w.sum(),1)
    
    #showing metadata
    print('\n\nFORECAST: {}'.format(state))
    print('\nNumber of polls included: {}'.format(len(x)))
    top5 = x.sort_values(by='w', ascending=False).head(5)[
            ['pollster', 'fte_grade', 'sample_size', 'population', 'methodology', 'end_date',
             'tracking', 'age', 'duration', 'w']]
    print('\nTop 5 highest-weighted polls:')
    print(top5)
        
    #showing forecast
    print('\nForecast:')
    print(pd.Series(forecast).sort_values(ascending=False))

# %% [markdown]
# ## Generating forecasts

# %% [markdown]
# #### National forecast

# %%
forecast(data, 'National', candidates=cands, max_results=3, max_age = 90,       
            p_fte_grade=w_fte_grade, p_population=w_population, p_methodology=w_methodology, p_tracking=w_tracking,
            p_sample_size=f_sample_size, p_age=f_age, p_duration=f_duration)
# Out:
# FORECAST: National
#
# Number of polls included: 55
#
# Top 5 highest-weighted polls:
#                                              pollster fte_grade  sample_size  \
# poll_id
# 62557                                 Morning Consult       B/C        16071
# 62536    Fox News/Beacon Research/Shaw & Co. Research        A-          471
# 62537                    NBC News/Wall Street Journal       A/B          414
# 62563                             Monmouth University        A+          345
# 62503                                 Morning Consult       B/C        15431
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 62557           lv      Online 2019-11-03     False    3         7  2.544276
# 62536           lv  Live Phone 2019-10-30     False    7         4  2.373795
# 62537           lv  Live Phone 2019-10-30     False    7         4  2.105229
# 62563           rv  Live Phone 2019-11-03     False    3         5  2.044748
# 62503           lv      Online 2019-10-27     False   10         7  2.021985
#
# Forecast:
# Biden        28.3
# Warren       21.1
# Sanders      16.9
# UNDECIDED    15.0
# Buttigieg     6.4
# Harris        5.1
# Yang          2.6
# Booker        2.1
# Klobuchar     1.8
# Steyer        0.7
# dtype: float64

# %% [markdown]
# #### State-by-state forecasts

# %%
for i in sorted(data.state.unique()):
    if i != 'National':
        forecast(data, state=i, candidates=cands, max_results=3, max_age = 365,       
                    p_fte_grade=w_fte_grade, p_population=w_population, p_methodology=w_methodology, p_tracking=w_tracking,
                    p_sample_size=f_sample_size, p_age=f_age, p_duration=f_duration)
# Out:
# FORECAST: Arizona
#
# Number of polls included: 4
#
# Top 5 highest-weighted polls:
#                                 pollster fte_grade  sample_size population  \
# poll_id
# 62508                    Emerson College        A-          339         lv
# 59598    Bendixen & Amandi International       B/C          250         rv
# 59778                    Change Research         C          396         lv
# 58455     Zogby Interactive/JZ Analytics         C          197         lv
#
#         methodology   end_date  tracking  age  duration         w
# poll_id
# 62508    IVR/Online 2019-10-28     False    9         4  2.307815
# 59598    Live Phone 2019-09-12     False   55         4  0.798929
# 59778        Online 2019-09-28     False   39         2  0.583818
# 58455        Online 2019-05-29     False  161         7  0.309438
#
# Forecast:
# Biden        26.8
# Warren       22.9
# Sanders      19.6
# UNDECIDED    10.3
# Buttigieg    10.2
# Yang          4.5
# Harris        3.9
# Klobuchar     1.4
# Booker        0.3
# Steyer        0.1
# dtype: float64
#
#
# FORECAST: California
#
# Number of polls included: 17
#
# Top 5 highest-weighted polls:
#                                       pollster fte_grade  sample_size  \
# poll_id
# 59776    Public Policy Institute of California       A/B          692
# 62442                          Change Research         C         1631
# 59708       University of California, Berkeley       B/C         2272
# 58757    Public Policy Institute of California       A/B          766
# 62228                                SurveyUSA         A          553
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 59776           lv  Live Phone 2019-09-25     False   42        10  2.008499
# 62442           lv      Online 2019-10-18     False   19         4  1.585339
# 59708           lv      Online 2019-09-18     False   49         6  1.524703
# 58757           lv  Live Phone 2019-07-23     False  106        10  1.407243
# 62228           lv      Online 2019-10-16     False   21         2  1.261221
#
# Forecast:
# Biden        21.9
# Warren       21.4
# Sanders      19.0
# UNDECIDED    13.3
# Harris       12.7
# Buttigieg     6.3
# Yang          2.7
# Booker        1.3
# Klobuchar     0.9
# Steyer        0.4
# dtype: float64
#
#
# FORECAST: Florida
#
# Number of polls included: 11
#
# Top 5 highest-weighted polls:
#                                 pollster fte_grade  sample_size population  \
# poll_id
# 59706               Tel Opinion Research       B/C          800         lv
# 59604        Florida Atlantic University       B/C          407         lv
# 58488              Quinnipiac University        B+          417         rv
# 57637    Bendixen & Amandi International       B/C          300         lv
# 58511                    Change Research         C         1130         lv
#
#         methodology   end_date  tracking  age  duration         w
# poll_id
# 59706    Live Phone 2019-09-18     False   49         4  2.924565
# 59604    IVR/Online 2019-09-15     False   52         4  1.356036
# 58488    Live Phone 2019-06-17     False  142         6  1.295523
# 57637    Live Phone 2019-03-04     False  247         4  0.852454
# 58511        Online 2019-06-17     False  142         2  0.812390
#
# Forecast:
# Biden        35.4
# UNDECIDED    25.8
# Warren       13.4
# Sanders      12.2
# Buttigieg     5.4
# Harris        5.2
# Yang          1.0
# Booker        1.0
# Klobuchar     0.6
# Steyer        0.0
# dtype: float64
#
#
# FORECAST: Georgia
#
# Number of polls included: 3
#
# Top 5 highest-weighted polls:
#                         pollster fte_grade  sample_size population  \
# poll_id
# 59579            Change Research         C          755         lv
# 59700    Landmark Communications         B          500         lv
# 58692               SurveyMonkey        D-          402         rv
#
#         methodology   end_date  tracking  age  duration         w
# poll_id
# 59579        Online 2019-09-11     False   56         5  1.663595
# 59700       Missing 2019-09-21     False   46         4  1.103814
# 58692        Online 2019-07-16     False  113        15  0.232591
#
# Forecast:
# Biden        35.9
# Warren       19.6
# Sanders      13.3
# UNDECIDED    12.1
# Harris        7.1
# Buttigieg     6.1
# Yang          2.7
# Booker        2.0
# Klobuchar     1.1
# Steyer        0.0
# dtype: float64
#
#
# FORECAST: Iowa
#
# Number of polls included: 27
#
# Top 5 highest-weighted polls:
#                                     pollster fte_grade  sample_size  \
# poll_id
# 62530    Siena College/New York Times Upshot        A+          439
# 59626                           Selzer & Co.        A+          602
# 61985                     Suffolk University        A-          500
# 58842                    Monmouth University        A+          401
# 58398                           Selzer & Co.        A+          600
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 62530           lv  Live Phone 2019-10-30     False    7         6  4.162087
# 59626           lv  Live Phone 2019-09-18     False   49         5  2.559901
# 61985           lv  Live Phone 2019-10-18     False   19         3  2.502123
# 58842           lv  Live Phone 2019-08-04     False   94         4  1.567806
# 58398           lv  Live Phone 2019-06-05     False  154         4  1.524476
#
# Forecast:
# Biden        21.9
# Warren       18.4
# UNDECIDED    17.9
# Sanders      15.0
# Buttigieg    12.0
# Harris        6.6
# Klobuchar     2.8
# Booker        2.2
# Steyer        1.6
# Yang          1.5
# dtype: float64
#
#
# FORECAST: Massachusetts
#
# Number of polls included: 5
#
# Top 5 highest-weighted polls:
#                       pollster fte_grade  sample_size population methodology  \
# poll_id
# 62237    MassINC Polling Group       A/B          456         lv  Live Phone
# 59503       Suffolk University        A-          500         lv  Live Phone
# 58410       Suffolk University        A-          370         lv  Live Phone
# 57834          Emerson College        A-          371         lv  Online/IVR
# 57181                   YouGov        B-          655         rv      Online
#
#           end_date  tracking  age  duration         w
# poll_id
# 62237   2019-10-20     False   17         5  2.168295
# 59503   2019-09-05     False   62         3  1.257890
# 58410   2019-06-09     False  150         5  0.834946
# 57834   2019-04-07     False  213         4  0.471710
# 57181   2018-11-14     False  357         8  0.267158
#
# Forecast:
# UNDECIDED    29.7
# Warren       23.9
# Biden        21.1
# Sanders      12.0
# Buttigieg     6.7
# Harris        3.7
# Klobuchar     0.9
# Booker        0.9
# Yang          0.8
# Steyer        0.4
# dtype: float64
#
#
# FORECAST: Michigan
#
# Number of polls included: 6
#
# Top 5 highest-weighted polls:
#                                pollster fte_grade  sample_size population  \
# poll_id
# 62538                   Emerson College        A-          454         lv
# 57656                   Emerson College        A-          317         lv
# 62437                    Denno Research   Missing          217         lv
# 58457    Zogby Interactive/JZ Analytics         C          268         lv
# 58748                     Climate Nexus   Missing          324         lv
#
#         methodology   end_date  tracking  age  duration         w
# poll_id
# 62538    IVR/Online 2019-11-03     False    3         4  3.837288
# 57656    Online/IVR 2019-03-10     False  241         4  0.702501
# 62437    Live Phone 2019-09-24     False   43         4  0.516660
# 58457        Online 2019-05-29     False  161         7  0.423407
# 58748        Online 2019-07-17     False  112         4  0.275909
#
# Forecast:
# Biden        33.4
# Sanders      24.1
# Warren       17.0
# UNDECIDED     9.4
# Buttigieg     6.4
# Harris        4.6
# Booker        2.3
# Yang          1.7
# Klobuchar     1.0
# Steyer        0.0
# dtype: float64
#
#
# FORECAST: Nevada
#
# Number of polls included: 10
# Top 5 highest-weighted polls:
#                     pollster fte_grade  sample_size population  \
# poll_id
# 62556          Mellman Group       B/C          600         lv
# 62539        Emerson College        A-          451         lv
# 59640     Suffolk University        A-          500         lv
# 59739                   SSRS       A/B          324         lv
# 58427    Monmouth University        A+          370         lv
#
#              methodology   end_date  tracking  age  duration         w
# poll_id
# 62556    Live Phone/Text 2019-11-02     False    4         6  2.318150
# 62539         IVR/Online 2019-11-03     False    3         4  2.063981
# 59640         Live Phone 2019-09-23     False   44         5  1.551124
# 59739         Live Phone 2019-09-26     False   41         5  1.216055
# 58427         Live Phone 2019-06-11     False  148         6  0.900984
#
# Forecast:
# Biden        27.6
# Warren       19.1
# Sanders      18.8
# UNDECIDED    15.1
# Buttigieg     5.5
# Harris        5.1
# Yang          3.1
# Steyer        2.9
# Booker        1.5
# Klobuchar     1.3
# dtype: float64
#
#
# FORECAST: New Hampshire
#
# Number of polls included: 27
#
# Top 5 highest-weighted polls:
#                                      pollster fte_grade  sample_size  \
# poll_id
# 62509             University of New Hampshire         B          574
# 60065    RKM Research and Communications Inc.       A/B          422
# 59641                     Monmouth University        A+          401
# 59541    RKM Research and Communications Inc.       A/B          425
# 58820                      Suffolk University        A-          500
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 62509           lv  Live Phone 2019-10-27     False   10         7  3.095266
# 60065           lv  Live Phone 2019-10-13     False   24         5  2.349443
# 59641           lv  Live Phone 2019-09-21     False   46         5  2.179500
# 59541           lv  Live Phone 2019-09-10     False   57         7  1.667202
# 58820           lv  Live Phone 2019-08-04     False   94         4  1.530262
#
# Forecast:
# Biden        22.9
# Warren       19.4
# UNDECIDED    18.0
# Sanders      18.0
# Buttigieg     8.7
# Harris        6.0
# Yang          2.2
# Klobuchar     1.9
# Booker        1.8
# Steyer        1.1
# dtype: float64
#
#
# FORECAST: North Carolina
#
# Number of polls included: 5
#
# Top 5 highest-weighted polls:
#                          pollster fte_grade  sample_size population  \
# poll_id
# 58840                   SurveyUSA         A          534         lv
# 59742       High Point University       A/B          348          a
# 58187             Emerson College        A-          397         lv
# 59917       Public Policy Polling         B          410          v
# 60063    East Carolina University   Missing          291         lv
#
#                methodology   end_date  tracking  age  duration         w
# poll_id
# 58840               Online 2019-08-05     False   93         5  1.614675
# 59742    Live Phone/Online 2019-09-19     False   48         7  1.144290
# 58187           IVR/Online 2019-06-03     False  156         4  1.012534
# 59917             IVR/Text 2019-10-06     False   31         3  0.733734
# 60063           IVR/Online 2019-10-09     False   28         8  0.494767
#
# Forecast:
# Biden        35.1
# Sanders      16.7
# Warren       15.6
# UNDECIDED    15.5
# Harris        6.2
# Buttigieg     5.7
# Yang          2.8
# Booker        1.8
# Klobuchar     0.8
# Steyer        0.0
# dtype: float64
#
#
# FORECAST: Ohio
#
# Number of polls included: 4
#
# Top 5 highest-weighted polls:
#                                pollster fte_grade  sample_size population  \
# poll_id
# 59820                   Emerson College        A-          353         lv
# 58733             Quinnipiac University        B+          556         rv
# 60067                     Climate Nexus   Missing          443         lv
# 58458    Zogby Interactive/JZ Analytics         C          222         lv
#
#         methodology   end_date  tracking  age  duration         w
# poll_id
# 59820    IVR/Online 2019-10-02     False   35         4  1.727691
# 58733    Live Phone 2019-07-22     False  107         6  1.339918
# 60067        Online 2019-10-07     False   30         7  0.555614
# 58458        Online 2019-05-29     False  161         7  0.376778
#
# Forecast:
# Biden        30.1
# Sanders      19.7
# Warren       17.3
# UNDECIDED    13.9
# Harris        8.8
# Buttigieg     5.4
# Yang          2.5
# Booker        1.1
# Steyer        0.6
# Klobuchar     0.5
# dtype: float64
#
#
# FORECAST: Pennsylvania
#
# Number of polls included: 7
#
# Top 5 highest-weighted polls:
#                                     pollster fte_grade  sample_size  \
# poll_id
# 62520            Franklin & Marshall College       B/C          226
# 57875                     Muhlenberg College        A+          405
# 59897    Susquehanna Polling & Research Inc.         C          307
# 58082                  Quinnipiac University        B+          431
# 58839            Franklin & Marshall College       B/C          295
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 62520           rv  Live Phone 2019-10-27     False   10         7  1.726411
# 57875           rv  Live Phone 2019-04-10     False  210         8  1.170849
# 59897           rv  Live Phone 2019-10-06     False   31         7  1.109420
# 58082           rv  Live Phone 2019-05-14     False  176         6  1.008541
# 58839           rv  Live Phone 2019-08-04     False   94         7  0.847148
#
# Forecast:
# Biden        30.6
# UNDECIDED    29.0
# Sanders      12.9
# Warren       12.5
# Buttigieg     6.7
# Harris        4.5
# Booker        2.2
# Klobuchar     1.3
# Yang          0.4
# Steyer        0.0
# dtype: float64
#
#
# FORECAST: South Carolina
#
# Number of polls included: 21
#
# Top 5 highest-weighted polls:
#                                              pollster fte_grade  sample_size  \
# poll_id
# 62242                             Monmouth University        A+          402
# 59857    Fox News/Beacon Research/Shaw & Co. Research        A-          803
# 59738                                            SSRS       A/B          406
# 60051                                          YouGov        B-          846
# 58648    Fox News/Beacon Research/Shaw & Co. Research        A-          701
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 62242           lv  Live Phone 2019-10-21     False   16         6  2.741765
# 59857           lv  Live Phone 2019-10-02     False   35         4  2.513344
# 59738           lv  Live Phone 2019-09-26     False   41         5  1.585860
# 60051           lv      Online 2019-10-11     False   26         9  1.407156
# 58648           lv  Live Phone 2019-07-10     False  119         4  1.376811
#
# Forecast:
# Biden        37.3
# UNDECIDED    19.2
# Warren       13.4
# Sanders      11.9
# Harris        7.2
# Buttigieg     3.8
# Booker        2.7
# Steyer        2.3
# Yang          1.2
# Klobuchar     0.9
# dtype: float64
#
#
# FORECAST: Texas
#
# Number of polls included: 16
#
# Top 5 highest-weighted polls:
#                       pollster fte_grade  sample_size population methodology  \
# poll_id
# 62541                   YouGov        B-          541         lv      Online
# 59535    Quinnipiac University        B+          456         rv  Live Phone
# 59533                   YouGov        B-          552         lv      Online
# 58702                   YouGov        B-          838         lv      Online
# 58821          Emerson College        A-          400         lv  IVR/Online
#
#           end_date  tracking  age  duration         w
# poll_id
# 62541   2019-10-27     False   10        10  2.459281
# 59535   2019-09-09     False   58         6  1.653233
# 59533   2019-09-08     False   59        11  1.313111
# 58702   2019-07-18     False  111        10  1.217917
# 58821   2019-08-03     False   95         3  1.072675
#
# Forecast:
# UNDECIDED    31.6
# Biden        24.7
# Sanders      13.9
# Warren       13.7
# Harris        5.9
# Buttigieg     5.4
# Yang          1.8
# Booker        1.5
# Klobuchar     1.1
# Steyer        0.3
# dtype: float64
#
#
# FORECAST: Virginia
#
# Number of polls included: 3
# Top 5 highest-weighted polls:
#                       pollster fte_grade  sample_size population methodology  \
# poll_id
# 59725    Research America Inc.       B/C          882         rv  Live Phone
# 58509       Hampton University       B/C         1126         rv      Online
# 58000          Change Research         C          551         lv      Online
#
#           end_date  tracking  age  duration         w
# poll_id
# 59725   2019-09-15     False   52        13  1.691659
# 58509   2019-06-06     False  153         9  0.781923
# 58000   2019-04-30     False  190         5  0.526417
#
# Forecast:
# UNDECIDED    30.0
# Biden        29.5
# Sanders      13.0
# Warren       10.2
# Buttigieg     7.2
# Harris        5.5
# Yang          1.6
# Booker        1.6
# Klobuchar     1.3
# Steyer        0.0
# dtype: float64
#
#
# FORECAST: Wisconsin
#
# Number of polls included: 9
#
# Top 5 highest-weighted polls:
#                                              pollster fte_grade  sample_size  \
# poll_id
# 59858    Fox News/Beacon Research/Shaw & Co. Research        A-          663
# 62431                 Marquette University Law School       A/B          379
# 59488                 Marquette University Law School       A/B          444
# 59893                                 Change Research         C          663
# 59892                                 Change Research         C         1261
#
#         population methodology   end_date  tracking  age  duration         w
# poll_id
# 59858           lv  Live Phone 2019-10-02     False   35         4  2.507111
# 62431           lv  Live Phone 2019-10-17     False   20         5  2.208666
# 59488           rv  Live Phone 2019-08-29     False   69         5  1.093239
# 59893           lv      Online 2019-10-02     False   35         4  0.903464
# 59892           lv      Online 2019-07-04     False  125         6  0.713979
#
# Forecast:
# Biden        25.4
# Warren       22.0
# Sanders      19.8
# UNDECIDED    13.7
# Buttigieg     7.3
# Harris        5.7
# Yang          2.1
# Klobuchar     2.1
# Booker        1.7
# Steyer        0.2
# dtype: float64
